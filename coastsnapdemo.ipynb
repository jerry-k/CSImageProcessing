# %%
from pathlib import Path

if Path.cwd().name != "CSImageProcessing":
    # !git clone https://github.com/jerry-k/CSImageProcessing
    # %cd CSImageProcessing
    # !pip install --progress-bar off --quiet -e .
# Out:
# Cloning into 'CSImageProcessing'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 56 (delta 25), reused 40 (delta 12), pack-reused 0
# Receiving objects: 100% (56/56), 2.52 MiB | 8.48 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# /content/CSImageProcessing
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.6.0 which is incompatible.
# ...

# %%
import os

current_directory = os.getcwd()

print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /content/CSImageProcessing

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

control = cv2.imread("Example/control.jpg")
control = cv2.cvtColor(control, cv2.COLOR_BGR2RGB)
mask = np.load("Example/mask.npy")
masked = control * mask[:,:,None]
plt.imshow(masked)
plt.show()

# %%
from imageprocessing.registration import Registration
from imageprocessing.images import download_images

# %%
download_images(topic_id=37, root_id=242186, no_images=50)

# %%
register = Registration("Example/control.jpg", mask)
register.generate_registrations()

# %%
# !zip -r /content/CSImageProcessing/registrations.zip /content/CSImageProcessing/registrations
# Out:
#   adding: content/CSImageProcessing/registrations/ (stored 0%)
#   adding: content/CSImageProcessing/registrations/registration8.jpeg (deflated 1%)
#   adding: content/CSImageProcessing/registrations/registration17.jpeg (deflated 0%)
#   adding: content/CSImageProcessing/registrations/registration4.jpeg (deflated 0%)
#   adding: content/CSImageProcessing/registrations/registration7.jpeg (deflated 0%)
#   adding: content/CSImageProcessing/registrations/registration5.jpeg (deflated 1%)
#   adding: content/CSImageProcessing/registrations/registration16.jpeg (deflated 0%)
#   adding: content/CSImageProcessing/registrations/registration6.jpeg (deflated 0%)
#   adding: content/CSImageProcessing/registrations/registration14.jpeg (deflated 0%)
#   adding: content/CSImageProcessing/registrations/registration9.jpeg (deflated 0%)
#   adding: content/CSImageProcessing/registrations/registration18.jpeg (deflated 0%)
# ...
